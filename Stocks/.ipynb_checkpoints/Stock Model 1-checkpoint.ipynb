# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web

# some sample code on stock fundamentals
# https://simply-python.com/2015/02/13/getting-historical-financial-statistics-of-stock-using-python/
# financials.morningstart.com is a great resource
# http://financials.morningstar.com/ratios/r.html?t=AAPL&region=arg&culture=en-US

# %%
import requests
key_ratios_url = 'http://financials.morningstar.com/finan/ajax/exportKR2CSV.html?&callback=?&t=XBUE:AAPL&region=arg&culture=en-US&cur=&order=asc'
response = requests.get(key_ratios_url)
print response
content = response.content
# financials_url = 'http://financials.morningstar.com/ajax/ReportProcess4CSV.html?&t=XBUE:AAPL&region=arg&culture=en-US&cur=&reportType=is&period=12&dataType=A&order=asc&columnYear=5&curYearPart=1st5year&rounding=3&view=raw&r=835563&denominatorView=raw&number=3'
# Out:
# <Response [200]>

# %%
content
# Out:
# '???Growth Profitability and Financial Ratios for Apple Inc ADR\nFinancials\n,2007-09,2008-09,2009-09,2010-09,2011-09,2012-09,2013-09,2014-09,2015-09,2016-09,TTM\nRevenue USD Mil,"24,578","37,491","42,905","65,225","108,249","156,508","170,910","182,795","233,715","215,639","215,639"\nGross Margin %,33.2,35.2,40.1,39.4,40.5,43.9,37.6,38.6,40.1,39.1,39.1\nOperating Income USD Mil,"4,407","8,327","11,740","18,385","33,790","55,241","48,999","52,503","71,230","60,024","60,024"\nOperating Margin %,17.9,22.2,27.4,28.2,31.2,35.3,28.7,28.7,30.5,27.8,27.8\nNet Income USD Mil,"3,495","6,119","8,235","14,013","25,922","41,733","37,037","39,510","53,394","45,687","45,687"\nEarnings Per Share USD,0.09,0.16,0.22,0.36,0.66,1.05,0.95,1.08,1.54,1.39,1.39\nDividends USD,,,,,,0.04,0.16,0.16,0.05,,\nPayout Ratio % *,,,,,,,16.4,15.5,6.5,,\nShares Mil,"37,343","37,882","38,087","38,830","39,331","39,697","39,122","36,729","34,751","32,995","32,995"\nBook Value Per Share * USD,,,,,8.29,,19.09,29.16,35.41,
# ...

# %%
# wiki invest EBIT http://www.wikinvest.com/stock/JOHNSON_&_JOHNSON_(JNJ)/Data/EBITDA/2000/Q4

# %%
# http://data.okfn.org/data/core/s-and-p-500-companies/r/constituents-financials.csv
sp500 = pd.read_csv('http://data.okfn.org/data/core/s-and-p-500-companies/r/constituents-financials.csv')
print sp500.shape
# Out:
# (504, 15)

# %%
sp500.head(2)
# Out:
#   Symbol                 Name       Sector   Price  Dividend Yield  \
# 0    MMM           3M Company  Industrials  177.12            2.53
# 1    ABT  Abbott Laboratories  Health Care   41.89            2.55
#
#    Price/Earnings  Earnings/Share  Book Value  52 week low  52 week high  \
# 0           22.77            7.78       19.34        134.0        177.79
# 1           25.79            1.62       14.10         36.0         51.74
#
#    Market Cap  EBITDA  Price/Sales  Price/Book  \
# 0      107.43    8.57         3.52        9.04
# 1       61.54    4.40         2.98        2.93
#
#                                          SEC Filings
# 0  http://www.sec.gov/cgi-bin/browse-edgar?action...
# 1  http://www.sec.gov/cgi-bin/browse-edgar?action...

# %%
f = web.DataReader("F", 'yahoo', pd.to_datetime('1990-01-01'), pd.to_datetime('2016-12-31'))

# %%
f
# Out:
#                  Open       High        Low      Close    Volume  Adj Close
# Date
# 1990-01-02  43.750039  45.250039  43.500039  45.250039   6241800   3.422794
# 1990-01-03  45.500039  45.875041  45.250039  45.500039   8031900   3.441704
# 1990-01-04  45.625041  45.750038  45.125041  45.500039   3932500   3.441704
# 1990-01-05  45.500039  45.750038  44.875041  44.875041   3820400   3.394428
# 1990-01-08  44.750039  45.000039  44.500039  44.875041   3360800   3.394428
# 1990-01-09  44.875041  45.125041  44.125036  44.125036   5279800   3.337696
# 1990-01-10  44.250039  44.500039  43.875036  44.500039   2950300   3.366062
# 1990-01-11  44.750039  45.375041  44.750039  45.000039   2944900   3.403883
# 1990-01-12  44.500039  44.625041  43.750039  43.750039   3214000   3.309331
# 1990-01-15  43.750039  43.875036  43.125039  43.250039   4010600   3.271510
# 1990-01-16  43.000037  45.125041  42.875037  45.000039   3935600   3.403883
# ...
