# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import scipy 
import statsmodels
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# http://pandas.pydata.org/pandas-docs/stable/remote_data.html

# %%
start = pd.to_datetime('2010-01-01')
end = pd.to_datetime('2016-06-01')
f = data.DataReader("F", 'yahoo', start, end)
f.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2010-01-04  10.17  10.28  10.05  10.28   60855800   8.755953
# 2010-01-05  10.45  11.24  10.40  10.96  215620200   9.335141
# 2010-01-06  11.21  11.46  11.13  11.37  200070600   9.684357
# 2010-01-07  11.46  11.69  11.32  11.66  130201700   9.931363
# 2010-01-08  11.67  11.74  11.46  11.69  130463000   9.956916

# %%
f['Adj Close'].plot()

# %%
aapl = data.Options('aapl', 'yahoo')
apple_data = aapl.get_all_data()
apple_data.head()
# Out:
#                                              Last   Bid    Ask  Chg  PctChg  \
# Strike Expiry     Type Symbol
# 10.0   2016-06-17 call AAPL160617C00010000  82.95  81.8  82.90  0.0     0.0
#                   put  AAPL160617P00010000   0.01   0.0   0.01  0.0     0.0
# 12.5   2016-06-17 call AAPL160617C00012500   0.00  88.5  88.95  0.0     0.0
#                   put  AAPL160617P00012500   0.00   0.0   0.03  0.0     0.0
# 15.0   2016-06-17 call AAPL160617C00015000   0.00  86.0  86.45  0.0     0.0
#
#                                             Vol  Open_Int      IV  Root  \
# Strike Expiry     Type Symbol
# 10.0   2016-06-17 call AAPL160617C00010000   20         0  0.0000  AAPL
#                   put  AAPL160617P00010000  100       100  3.6250  AAPL
# 12.5   2016-06-17 call AAPL160617C00012500    0         0  9.3438  AAPL
#                   put  AAPL160617P00012500    0         0  3.5625  AAPL
# 15.0   2016-06-17 call AAPL160617C00015000    0         0  8.3740  AAPL
#
#                                            IsNonstandard Underlying  \
# Strike Expiry     Type Symbol
# 10.0   2016-06-17 call AAPL160617C00010000         False       AAPL
#                   put  AAPL160617P00010000         False       AAPL
# 12.5   2016-06-17 call AAPL160617C00012500         False       AAPL
#                   put  AAPL160617P00012500         False       AAPL
# 15.0   2016-06-17 call AAPL160617C00015000         False       AAPL
#
#                                             Underlying_Price  \
# Strike Expiry     Type Symbol
# 10.0   2016-06-17 call AAPL160617C00010000             97.72
#                   put  AAPL160617P00010000             97.72
# 12.5   2016-06-17 call AAPL160617C00012500             97.72
#                   put  AAPL160617P00012500             97.72
# 15.0   2016-06-17 call AAPL160617C00015000             97.72
#
#                                                     Quote_Time
# Strike Expiry     Type Symbol
# 10.0   2016-06-17 call AAPL160617C00010000 2016-06-02 16:00:00
#                   put  AAPL160617P00010000 2016-06-02 16:00:00
# 12.5   2016-06-17 call AAPL160617C00012500 2016-06-02 16:00:00
#                   put  AAPL160617P00012500 2016-06-02 16:00:00
# 15.0   2016-06-17 call AAPL160617C00015000 2016-06-02 16:00:00

# %%
gdp = data.DataReader("GDP", "fred", start, end)
gdp.head()
# Out:
#                 GDP
# DATE
# 2010-01-01  14681.1
# 2010-04-01  14888.6
# 2010-07-01  15057.7
# 2010-10-01  15230.2
# 2011-01-01  15238.4

# %%
ip = data.DataReader("5_Industry_Portfolios", "famafrench")
ip[0]
# Out:
#          Cnsmr  Manuf  HiTec  Hlth   Other
# Date
# 2010-01  -1.95  -4.02  -7.59   0.00  -1.67
# 2010-02   3.90   3.23   4.34   0.37   3.38
# 2010-03   6.35   4.74   6.86   3.61   8.42
