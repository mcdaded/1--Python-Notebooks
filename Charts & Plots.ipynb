# %%
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
x = np.array(['1. Bubble Tea', '2. Sketch Comedy', '3. Endings', '4. Unfunny things', '5. A Guy', '6. Ten Minutes', '7. All of the Above', '8. Imagining Lex'])
y = np.array([0, 0, 0, 0, 0, 0, 0, 1])

# %%
sns.barplot(x, y, ci=None, palette="Paired")
#sns.barplot()
#sns.set_xticklabels(rotation=30)
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
plt.ylim(ymax = 3, ymin = 0)
plt.yticks([1, 2, 3])
plt.ylabel("Responses")
plt.xlabel("Categories")
plt.title("Status Update Intrests")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", context="talk")
rs = np.random.RandomState(7)

x = np.array(list("ABCDEFGHI"))

f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 6), sharex=True)

y1 = np.arange(1, 10)
sns.barplot(x, y1, ci=None, palette="BuGn_d", hline=.1, ax=ax1)
ax1.set_ylabel("Sequential")

y2 = y1 - 5
sns.barplot(x, y2, ci=None, palette="coolwarm", hline=0, ax=ax2)
ax2.set_ylabel("Diverging")

y3 = rs.choice(y1, 9, replace=False)
sns.barplot(x, y3, ci=None, palette="Paired", hline=.1, ax=ax3)
ax3.set_ylabel("Qualitative")

sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=3)

# %%
y3
# Out:
# array([3, 8, 1, 9, 6, 4, 7, 2, 5])

# %%
x
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'],
#       dtype='|S1')
